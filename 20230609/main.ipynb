# %%
import pandas as pd

data = pd.read_csv('gpascore.csv')
# data

# 데이터 전처리
# 값이 없는 데이터가 있을 때 평균값을 넣거나, 행을 삭제
# data의 빈 칸이 몇 개인지 확인하고 싶을 때
# data.isnull().sum()

# NaN/빈칸이 있는 행을 제거
data = data.dropna()
# data.isnull().sum()

# 빈칸을 원하는 값으로 채움
# data = data.fillna(100)
# data.isnull().sum()

data['gpa']
# 최소값
data['gre'].min()
# 최대값
data['gre'].max()
# 열 수
data['gre'].count()

y데이터 = data['admit']
y데이터 = data['admit'].values
# y데이터

x데이터 = []

for i, rows in data.iterrows():
    x데이터.append([rows['gre'],rows['gpa'],rows['rank']])
    
x데이터
# Out:
# [[380.0, 3.21, 3.0],
#  [660.0, 3.67, 3.0],
#  [800.0, 4.0, 1.0],
#  [640.0, 3.19, 4.0],
#  [520.0, 2.33, 4.0],
#  [760.0, 3.0, 2.0],
#  [560.0, 2.98, 1.0],
#  [400.0, 3.08, 2.0],
#  [540.0, 3.39, 3.0],
#  [700.0, 3.92, 2.0],
#  [750.0, 3.6, 4.0],
#  [440.0, 3.22, 1.0],
#  [760.0, 4.0, 1.0],
#  [600.0, 3.08, 2.0],
#  [700.0, 4.0, 1.0],
#  [480.0, 3.44, 3.0],
#  [490.0, 3.87, 4.0],
#  [360.0, 2.56, 3.0],
#  [800.0, 3.75, 2.0],
#  [500.0, 3.17, 3.0],
#  [660.0, 3.63, 2.0],
#  [600.0, 2.82, 4.0],
#  [680.0, 3.19, 4.0],
#  [760.0, 3.35, 2.0],
#  [800.0, 3.66, 1.0],
#  [620.0, 3.61, 1.0],
#  [520.0, 3.74, 4.0],
#  [780.0, 3.22, 2.0],
#  [520.0, 3.29, 1.0],
#  [540.0, 3.78, 4.0],
#  [760.0, 3.35, 3.0],
#  [600.0, 3.4, 3.0],
#  [800.0, 4.0, 3.0],
#  [360.0, 3.14, 1.0],
#  [400.0, 3.05, 2.0],
#  [580.0, 3.25, 1.0],
#  [520.0, 2.9, 3.0],
#  [500.0, 3.13, 2.0],
#  [520.0, 2.68, 3.0],
#  [560.0, 2.42, 2.0],
#  [580.0, 3.32, 2.0],
#  [600.0, 3.15, 2.0],
#  [500.0, 3.31, 3.0],
# ...

# %%
import numpy as np

x데이터 =  np.array(x데이터)

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64,  activation='tanh'),
    tf.keras.layers.Dense(128, activation='tanh'),
    tf.keras.layers.Dense(1,   activation='sigmoid'),
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(x데이터, y데이터, epochs=100)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7138 - accuracy: 0.4894
# Epoch 2/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6871 - accuracy: 0.5388
# Epoch 3/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.7044 - accuracy: 0.4965
# Epoch 4/100
# 14/14 [==============================] - 0s 772us/step - loss: 0.6782 - accuracy: 0.5812
# Epoch 5/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6923 - accuracy: 0.5271
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6763 - accuracy: 0.5953
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6670 - accuracy: 0.6282
# Epoch 8/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6594 - accuracy: 0.6165
# Epoch 9/100
# 14/14 [==============================] - 0s 805us/step - loss: 0.6568 - accuracy: 0.6235
# Epoch 10/100
# ...

# %%
# 예측

# GRE 성적이 700, 학점이 3.7, 4등급 학교에 지원하고 싶어요
# 합격확률은 어떻게 될까요?

# 만들어진 model로 y값 예측해주세요
예측값 = model.predict([[700, 3.7, 4], [750, 3.7, 3], [400, 2.2, 1]])
예측값
# Out:
# 1/1 [==============================] - 0s 69ms/step
# array([[0.5760595 ],
#        [0.6547329 ],
#        [0.56228465]], dtype=float32)

# %%
import pandas as pd

data = pd.read_csv('gpascore.csv')

data.isnull().sum()
data = data.dropna()

y데이터 = data['admit'].values

x데이터 = []

for i, rows in data.iterrows():
    x데이터.append([rows['gre'],rows['gpa'],rows['rank']])

# %%
# 예측
# 만들어진 model로 y값 예측해주세요
예측값 = model.predict([[700, 3.7, 4], [750, 3.7, 3], [400, 2.2, 1]])
예측값
